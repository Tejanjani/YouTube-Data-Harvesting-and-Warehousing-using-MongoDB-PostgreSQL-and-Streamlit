# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %%
#API Key Connection

def Api_connect():
    Api_Id= "AIzaSyD4DxclgbUCxTlbvpka94GK4meTKSUduDY"

    api_service_name= "youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
#get channel information
def get_channel_info(channel_id):
    request=youtube.channels().list(
                    part= "snippet,ContentDetails,statistics",
                    id=channel_id
    )
    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_id=i["id"],
                Subscribers=i['statistics']['subscriberCount'],
                Views=i["statistics"]["viewCount"],
                Total_Videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details=get_channel_info("UChGd9JY4yMegY6PxqpBjpRA")

# %%
channel_details
# Out:
# {'Channel_Name': 'Science With Sam - அறிவியல் அறிவோம் !',
#  'Channel_id': 'UChGd9JY4yMegY6PxqpBjpRA',
#  'Subscribers': '59800',
#  'Views': '3960725',
#  'Total_Videos': '261',
#  'Channel_Description': 'நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பானில் 1.5 வருட ஆராய்ச்சி, அமெரிக்காவில் 2 வருட ஆராய்ச்சி, ஐரோப்பாவில் சுமார் 6 வருட ஆராய்ச்சி ! தற்போது நம்ம ஊரில்  !\n\nஎளிய தமிழில் அனைவரும் ஆர்வமுடன் அறிவியலை தெரிந்துகொள்ளவேண்டும் என்ற நோக்கத்தில் இந்த முயற்சி! என்னுடன் தொடர்பு கொள்ள விரும்பினால் sciencewithsam2020@gmail.com\n\nConnect with me by email sciencewithsam2020@gmail.com\n\nநான் யாரிடமும் பணமோ உதவியோ இந்த சேனல் மூலம் கேட்பதில்லை. ஒரு வேலை என்னுடைய சேனலுக்கு உதவ விரும்பும் நண்பர்கள், தனிப்பட்ட முறையில் மின்னஞ்சல் அனுப்பலாம் \n\nI never ask for money through my channel. If you really want to support my work by any means, write to me personally at my email ID sciencewithsam2020@gmail.com \n\n',
#  'Playlist_Id': 'UUhGd9JY4yMegY6PxqpBjpRA'}

# %%
#get video ids
def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,part='contentDetails').execute()

    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:
        response1=youtube.playlistItems().list(part='snippet',playlistId=Playlist_Id,maxResults=50,pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')  # Corrected accessing 'nextPageToken' using .get() method

        if next_page_token is None:
            break
    return video_ids

Video_Ids = get_videos_ids("UChGd9JY4yMegY6PxqpBjpRA")

# %%
Video_Ids=get_videos_ids("UChGd9JY4yMegY6PxqpBjpRA")

# %%
len(Video_Ids)
# Out:
# 261

# %%
Video_Ids
# Out:
# ['yksgUtc4F5M',
#  'GW7tQGoQSMA',
#  'K5OoR-Uo7xM',
#  'QkPhSjo7nsI',
#  'pSLahAy8nC4',
#  'JgzEOrPmaDI',
#  'FTLBylwmrlk',
#  'fjcoW3dtuGM',
#  'IezbYe4KnAg',
#  'Sso4-56DB_g',
#  'D3jiAxVmYr4',
#  'qK3WhbtnYiE',
#  'u8Taq7BftzI',
#  'axyB8eJfA_g',
#  'jUuXuT8OCCc',
#  'G2Hpsf6VjII',
#  'q7CCuy-z16w',
#  '4OzQep0O188',
#  'NLt8jvfRzdE',
#  'YlBN1q_C36g',
#  'I8-ePNI1dOA',
#  'lRsV8HPNmOs',
#  'BKeyxTrBbnY',
#  'fK-9tNPZwl0',
#  '3YLM4syCmm8',
#  'j58-HbDWRww',
#  'hFwavrH8BLU',
#  'UfutXnYu7R8',
#  'uQuwBs7RJHw',
#  'KpuRyc00_t0',
#  'E5O7Nx6lpu0',
#  'qIyIA68T1FY',
#  'PoS7ifimbpk',
#  'NlvuPsZtQJw',
#  'UaBKxzBhdqk',
#  'mRBCCWoK2Qw',
#  'd4Cz8Vcg3tY',
#  'hoJw8D4DrLc',
#  'uob4vPknXkI',
#  'fnnqJ_COroo',
#  'uj2t-A2zACM',
#  'UmCb-7mNREE',
#  'mMpvW8cZDwo',
#  'N6ZV9jPQok0',
#  'RPfhLGAKK3Q',
#  'ruxVRaCchtI',
#  '85aiJYOdK_w',
#  'qqb3HazZLMs',
#  '6yIDo13llWQ',
#  'G6Zvjkz_hSM',
#  '1Vtr7-kWB4I',
#  'tjRZK_1XAro',
#  'mieGqJ0BXiE',
#  'rggw1Izwbf0',
#  'wk30gfF_C_w',
#  'w8D181wzNAE',
#  'Rsv1Gee1X3k',
#  'Uug8GbypVeE',
#  'w-skmswzslw',
#  '-WCqyL_maXw',
#  'IkUnfZ3DZ5E',
#  'UMJNo2AsBIw',
#  'GzsO5iDWFzE',
#  '0F9yBSVORiw',
#  '0m_GL1s48PM',
#  'SahrxeFDOTU',
#  'cklmbSyiDWw',
#  'W-cOYQenl-8',
#  '40nAkEJzQfU',
#  'Z-EXgiNUBA4',
#  '2-RF5URMwiA',
#  'vzh3TNGvRoI',
#  'YDAHEdLFKlw',
#  'jeQMuKJLL6c',
#  'JIfhCzk0Qe0',
#  'OsxGwNSqsoQ',
#  'Ih3K9C6Am4o',
#  'lEMEFIill2w',
#  'xiND3txiVUU',
#  'PAT1VMOf-g4',
#  '9e17CXMgCew',
#  'wtD7UflK1qw',
#  'OrpxceNF4CM',
#  'FxhUEKmr6Z4',
#  's4WDqiSO5xA',
#  'QtHKeTvJZVg',
#  'ydROlWxg-F0',
#  'TAZsy6eW5lg',
#  '-Bm8pkfEyV4',
#  'NgevvQ07AE0',
#  'TY7fWhxW5kc',
#  'pqHbuJG3slw',
#  'nYsz_d6GwfE',
#  'TitA0sTkEG0',
#  'ZWVQkdzu73A',
#  '6bI3ANM6XVk',
#  '1-LYbjM2Dqk',
#  'SZ1okoINcMQ',
#  'm6oQJtgEBc4',
#  'txOSCaXeIWk',
#  'zZYgvfIG9Tg',
#  '0lotQT0RVHw',
#  'qIkrm8IOqMw',
#  'fypZd-LX9MM',
#  'HzGvRiMIOYw',
#  'ggZ42AbcO6E',
#  '__Oy83p64SU',
#  'IQAHqC6GXdY',
#  '4WB05Uuaitc',
#  'NLggvZqb4-A',
#  'TM7P3ZfUnl0',
#  'R5lq1cQdCBo',
#  'ecmXIbNuwVA',
#  'gttiv7cJXpQ',
#  'Yybi0qnfWgU',
#  'frvYbjWXOKw',
#  'akO3XwAvBGY',
#  'k3Iav37Df9E',
#  'L4jk1isSuOI',
#  '2kgB7i2hH-c',
#  'af4EHM2pbmQ',
#  'mZZMzF11zaE',
#  'bgFrMm2XgFg',
#  'BZ7VcMdeD3g',
#  'PSsClm5m1Bo',
#  '_O6rhPY4QR0',
#  'oZ94AdtLm4o',
#  '-5Y92EMuc5E',
#  '6f1munXQUoo',
#  'gwkGzXAcSL8',
#  'rtGuRxg6i84',
#  'ParjXaRce58',
#  'hVMwDfDcWJ4',
#  'mRrmkHxd3QY',
#  'FlbmzyDQMu4',
#  'lL9xjotTiog',
#  'uZ8-8dOMEjc',
#  'bXqPDI75_d4',
#  'YuR3x9rr9OI',
#  '9pfjECrgtvQ',
#  'x4PPCViqQ1I',
#  'gToa-y6QoUk',
#  '0Uc5O7ICfXk',
#  'J5ojfRvs6ho',
#  'EKqPOy0GYds',
#  'fXORmRmN9Dg',
#  'le9Gma-pwzc',
#  'cjkTNVYP1KA',
#  'YOAh6pioIEc',
#  'N-slORdrSPs',
#  '-hs3mIAcyV8',
#  'Mb-5T6TArYs',
#  'frNtVnFnLBc',
#  'AUztMVwjo5g',
#  'rWaSAg0QjgQ',
#  'Up5Xu7fmOgg',
#  'KKT7353JKhw',
#  '6QLhrenhvM4',
#  'hWQQJcjjNHc',
#  'LthMtYl2Snw',
#  'HmQVFXLbYOM',
#  'Bi7g_umT1dY',
#  'uw036FhAsZc',
#  'GlFl1XLv0FY',
#  '0BmrMyI5E1w',
#  '0vGybNs0DJo',
#  '3-TiYWpL9mY',
#  '2kl5TNjskAk',
#  '4PC4PDFawV4',
#  'Gm22nTZqJUk',
#  'JshtVqvJwMQ',
#  'x8kkBTsIFf8',
#  'gU_qHITVDeE',
#  'gLYmttnvpCQ',
#  '5ddKRkJd5ts',
#  '7mNTQzaXp20',
#  'KiVH9gSMVIk',
#  'KxeD1bYJlt0',
#  '24W2GZagFnw',
#  'G37JWyJRwe0',
#  '3TUzC2yyr4s',
#  'BRrNRwvlHVk',
#  'B4A1h2bTdDY',
#  'o61cfHWRuD4',
#  'h4vxjVxdWME',
#  'uRcF7_pClSM',
#  '_xY8Qz6vb8I',
#  'gM70BEUS9aw',
#  'UkmpZ4vzqh0',
#  'azy3h1YQVik',
#  'ce-E-pmoZ4c',
#  'bLOi1bSUBvs',
#  'BKDv0TApWvY',
#  'lfhFgzT-5Kc',
#  'zB0p8WSMW8U',
#  'RU26gxKpf1k',
#  'GHPpYngk9rs',
#  '5_ozhqxuM0c',
#  'dGuW19nOWHw',
#  'tdpj78n3y3E',
#  'Fmn57AJGbsA',
#  'L82uJC1EgRk',
#  '3yiHw36iUgk',
#  '9lBobn-UGPg',
#  'xu15uzuEiuk',
#  'HsfKtMROCWg',
#  'KgEYn2WLFHk',
#  'LK8qdNg3cBI',
#  'yQqsfC4Pw8s',
#  'wjYs45ScBA8',
#  '-q0SL8Cm_F0',
#  'J1OdDFeXQn0',
#  'o3M0qbUUHW0',
#  'weUZl1gSsvg',
#  'eSPGDQja8Qg',
#  '-B9y18v96Os',
#  '6RyDc-D2f7g',
#  'CUPz-E-C3ug',
#  'CbRrXRuJg0c',
#  'MByMwmqrNiI',
#  'CsJGd5zqJQI',
#  'bEJXVQYdhMU',
#  'CLgfReYJ2rk',
#  'GbzUpKysCqg',
#  'icPAhpbYAYQ',
#  '5Kjk2LepbsE',
#  '2l8xcWvMfPM',
#  'tV_rpUWvZEM',
#  'a1p-YN2m--4',
#  '3B_nkzvU_XQ',
#  'YBV9X3cy-YI',
#  'NufjXnBa3fU',
#  'lJG2Is_uOPo',
#  'ogncVQNVBs0',
#  'g4Cv0qmNpkM',
#  'dW1Du_zgYwQ',
#  'QusGXbGm7gI',
#  'iz8Rh9HCutc',
#  'pajRi7pt0C0',
#  'Nykz9_Vh2Bo',
#  'zcvArp8CSrk',
#  'DUxNSZg95m8',
#  'VPdRgL9Wlho',
#  'MYEpZs9zqFQ',
#  'QYUdzoW8Ecw',
#  'rkt_wMoIz3U',
#  '7pp90cY3cws',
#  'jLxX9QCf3zs',
#  'lGUocqYnDtQ',
#  'wQtxHEpWtLc',
#  'J0j9KPDjPXI',
#  'vhKlZIV_9Lg',
#  'X6Zgh_Ww9qk',
#  'pHVUjoiC8ts',
#  'mFbIdGkmGQ0',
#  'CK-Z2H23aNY',
#  'r4atlpx48Ow',
#  'o2YAzhcnN30',
#  'cFd0i4UyPpU',
#  'sAuoNwN2qMU',
#  'rFnCy_tn5Lo']

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount') ,
                    Likes=item['statistics'].get('likeCount'),
                    Comments=item['statistics'].get('commentCount'),
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_Status=item['contentDetails']['caption']
                    )
            video_data.append(data)
    return video_data

# %%
#get comment information

def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                
                Comment_data.append(data)

    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
len(comment_details)
# Out:
# 8695

# %%
comment_details
# Out:
# [{'Comment_Id': 'UgzBSZqVoc2NzV_u_a14AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Ennum unga channel popular aganum ❤🎉',
#   'Comment_Author': '@jaganvanne',
#   'Comment_Published': '2024-04-09T17:23:32Z'},
#  {'Comment_Id': 'UgxKcs5I0wrx5Yz-BQh4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Hi sir <br><br>Neenga amc 🤩🤩🤩🤩',
#   'Comment_Author': '@user-pd3rc5ph7x',
#   'Comment_Published': '2024-03-28T15:36:20Z'},
#  {'Comment_Id': 'UgxJpVYrxn7RaINau7p4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Keep uploading videos',
#   'Comment_Author': '@user-pd3rc5ph7x',
#   'Comment_Published': '2024-03-28T15:34:24Z'},
#  {'Comment_Id': 'Ugzsnyhi7a-92JfJEIZ4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'பல ஒளி ஆண்டுகள் தள்ளி இருக்கும் ஒரு பொருள் இல் அல்லது planet இன் பரப்பில் என்னன்ன உலோகங்கள் இருக்கின்றன என்பதை கூட இதை வைத்து கண்டுபிடிக்க முடியும்',
#   'Comment_Author': '@kircyclone',
#   'Comment_Published': '2024-03-10T09:06:53Z'},
#  {'Comment_Id': 'UgxjCoj5wLJVRb80_oh4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'எனக்கும் திருப்பி ஒரு முறை திரு மிகு ராமன் அவர்கள் பற்றி படித்தது போல் மகிழ்ச்சி அடைகிறேன், வாழ்த்துக்கள்',
#   'Comment_Author': '@sivan1192',
#   'Comment_Published': '2024-03-09T18:30:09Z'},
#  {'Comment_Id': 'UgzOw2Y847anRRiWozR4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Salutes to Sir C V Raman',
#   'Comment_Author': '@user-mc7le5fo7n',
#   'Comment_Published': '2024-03-09T15:09:22Z'},
#  {'Comment_Id': 'UgyW7lOIrHsjKj8-P6F4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'நல்ல பதிவு.<br>ஆனால், பெருமிதம் தரும் சொற்பொழிவுக்கு இடையே<br>&quot;இந்தியா அடிமை பட்டிருந்தது நாம் அடிமைகளாய் இருந்தோம். இந்தியா என்ற நாடே இல்லை&quot;<br>என்ற சர்ச்சைக்குரிய  விஷயத்தை தவிர்த்திருக்கலாம்.',
#   'Comment_Author': '@user-ce5rm3tf1s',
#   'Comment_Published': '2024-03-08T18:48:30Z'},
#  {'Comment_Id': 'UgyJffYvplD2USkpkOJ4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Good',
#   'Comment_Author': '@AfqAhd-rm5yi',
#   'Comment_Published': '2024-03-07T13:17:03Z'},
#  {'Comment_Id': 'Ugz7et1xz287NU-5EZx4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'thank you for good explanation',
#   'Comment_Author': '@shameeraschool4807',
#   'Comment_Published': '2024-03-05T03:27:00Z'},
#  {'Comment_Id': 'UgwUp6Ka6eNDxnT19ip4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'After 1.5 yr later I&#39;m seeing you again in a different account.when i was seeing you in lockdown time i was trying to help you edit your video. I wanted  you to be a great YouTuber in scienc but I&#39;m work from office bro.feel sry not to help you right now',
#   'Comment_Author': '@arun.9154',
#   'Comment_Published': '2024-03-02T16:44:51Z'},
#  {'Comment_Id': 'UgxrZxHcaldzPcCyqoV4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Thank you sir',
#   'Comment_Author': '@orientmotors9869',
#   'Comment_Published': '2024-03-01T09:56:25Z'},
#  {'Comment_Id': 'UgzxZ7mXSJ0zIY_7O6d4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Rosalind franklin life pathi poduga sir',
#   'Comment_Author': '@dharanidharan.s',
#   'Comment_Published': '2024-02-29T15:42:46Z'},
#  {'Comment_Id': 'UgxfacMcZ15NDhAH5YN4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Raman loved Flowers as they are having special colours. Many of the flowering plants of Raman Research Institute were planted during the times of Raman. The original spectrometer developed by Raman is kept at RRI. When I see the published paper on scattering events in Benzene, similar to Curie&#39;s atomic weight precisions, - I used to excite. A sincere dedicated life is evident here. I hope we can expect surprising thoughts for March 14..😍😍😎😎',
#   'Comment_Author': '@kannadassasn',
#   'Comment_Published': '2024-02-29T08:22:54Z'},
#  {'Comment_Id': 'UgwqiL9u44IX5iTyTHR4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'This method using for space that&#39;s really awesome',
#   'Comment_Author': '@mrvigneshviki7269',
#   'Comment_Published': '2024-02-29T03:31:46Z'},
#  {'Comment_Id': 'UgxQeObQoDB2EDWrSoR4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'அரிய கண்டுபிடிப்புகள்<br>எளிய மனிதர்கள் வழியாகக் கூட<br>நிகழக் கூடும்...<br><br>முயற்சியும், ஆர்வமும், நேரமும்<br>கைகூட வேண்டும்...<br><br>❤🙏❤',
#   'Comment_Author': '@saravanank3204',
#   'Comment_Published': '2024-02-28T20:19:38Z'},
#  {'Comment_Id': 'UgyogKdgVpof9B3N7oJ4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'ராமன் எபெக்ட் கண்டுபிடிக்கப்பட்ட நாள் அன்று நாட்டின் அறிவியல் தினத்தைக் கொண்டாடிக் கொண்டு இருக்கிறோம். நகைப்பாக இருக்கிறது. அறிவியலாளர் என்றால் இங்கே ஆண்கள் தான்.<br><br>பெண்களுக்கு தன் ஆய்வகத்தில் இடமில்லை என மறுத்த ராமனிடம் போராடி, &quot;பார்ட் டைம்&quot; ஆய்வாளராக சேர்ந்து அறிவியலில் முனைவர் பட்டம் பெற்ற முதல் பெண் ஆனவர் கமலா சோஹானி. அதே ராமனிடம் மல்லு கட்ட முடியாமல், முனைவர் பட்ட கனவை கைகழுவி இங்கிலாந்துக்கு பயணித்து பட்டம் முடித்து, பின்னாளில் நாட்டின் weather woman ஆனவர் அன்னா மானி. (அன்னாவை இந்தியா அழைத்து வந்தவர் நேரு❤️)<br><br>அன்னா, கமலா போல பிழைத்துக் கிடக்காமல், மேல் படிப்பைத் தொடரும் வாய்ப்பு இருந்தும், தற்கொலை செய்துகொண்டு இறந்து போனவர் ஆய்வாளரும் ராமனின் மாணவருமான சுனந்தா பாய். ராமன் எத்தனை பெண் வெறுப்பு கொண்டவராக, பாலின சமத்துவத்தை விரும்பாதவராக இருந்தார் என கமலாவும், அன்னாவும் பதிவு செய்திருக்கிறார்கள். ஆனால் பாருங்கள், இந்தப் பெண்களை எல்லாம் அறிவியல் நாளில் நினைவு கொள்வாரில்லை!<br><br>இன்று எங்கெங்கு நோக்கினும் ராமனைப் புகழ்ந்து பாக்கள் எழுதப்பட்டுக் கொண்டிருக்கின்றன. Hypocrisy. அறிவியல் பெண்களைக் கொண்டாடுவோம். இந்த நாள் ஒன்றும் பெரிய நாள் அல்ல. இன்று இந்தியாவில் 46% பெண்கள் ஸ்டெம் துறையில் பணியாற்றுகின்றனர். ஐரோப்பிய நாடுகளான பிரான்ஸ் (32%), ஜெர்மனி (26%) போன்ற நாடுகளை இந்தியப் பெண்கள் பின்னுக்குத் தள்ளி இருக்கிறார்கள். ஆனாலும் இந்த 46%ல் உயர் பதவிகளில் இருக்கும் பெண்கள் எண்ணிக்கை ஆய்வுக்குறியது. இந்தப் பெரும் சமூக மாற்றத்துக்கான விதையை ஊன்றியவர்கள், மேலே குறிப்பிட்டுள்ள பெண்கள். Is it not time to celebrate the right people at the right time? யாரைக் கொண்டாடுகிறோம் என கொஞ்சம் நிறுத்தி நிதானமாக சிந்திக்க வேண்டும்! That&#39;s all. That&#39;s the point.',
#   'Comment_Author': '@foster6818',
#   'Comment_Published': '2024-02-28T17:38:57Z'},
#  {'Comment_Id': 'UgynW_Zj2c6HSS0sYWR4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'மிக அருமை',
#   'Comment_Author': '@kalaiselvan6761',
#   'Comment_Published': '2024-02-28T16:12:14Z'},
#  {'Comment_Id': 'UgwYMptYPIYv63lF5EF4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Thank you sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-02-28T15:34:58Z'},
#  {'Comment_Id': 'UgwQZs7zxELHhB0uuHl4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'A good explanation skill very important for all the science students<br><br>National Science day to sir🎉🎉🎉🎉',
#   'Comment_Author': '@HariHaran-sw3le',
#   'Comment_Published': '2024-02-28T14:58:55Z'},
#  {'Comment_Id': 'UgzRtzm1diLnXnZHNb54AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Excellent information',
#   'Comment_Author': '@Mathematics0227',
#   'Comment_Published': '2024-02-28T14:39:43Z'},
#  {'Comment_Id': 'Ugweca11me2aCPbvexJ4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'நல் வாழ்த்துகள் நண்பா',
#   'Comment_Author': '@rajuc9392',
#   'Comment_Published': '2024-02-28T13:00:22Z'},
#  {'Comment_Id': 'Ugwf5xvYWtALnYzWAit4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Very simply explained sam fine.Thanks a lot to mesmerise spectroscopy',
#   'Comment_Author': '@anantabaskarkannayan4262',
#   'Comment_Published': '2024-02-28T12:45:49Z'},
#  {'Comment_Id': 'UgyCBuL_nN3GJqJwWeF4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Vikshith bharat என்றால் வளர்ந்த பாரதம்!!',
#   'Comment_Author': '@kumarankumaran3947',
#   'Comment_Published': '2024-02-28T11:29:56Z'},
#  {'Comment_Id': 'UgwmiwP5B55sTAs7b_R4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Nice presentation.Superb.',
#   'Comment_Author': '@kunjithapatham3329',
#   'Comment_Published': '2024-02-28T09:16:10Z'},
#  {'Comment_Id': 'Ugyteis4lQeIyv1yawB4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'வாழ்த்துக்கள்',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-02-28T05:45:03Z'},
#  {'Comment_Id': 'Ugxb5VOC7uwMe3SohTt4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Schrodinger life story video podunga bro',
#   'Comment_Author': '@trollboy7709',
#   'Comment_Published': '2024-02-28T04:22:46Z'},
#  {'Comment_Id': 'UgxmZTT07MKDPSFxx3p4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Thanks for helping my தியரி.',
#   'Comment_Author': '@user-tz5kp8bo6d',
#   'Comment_Published': '2024-02-28T04:13:17Z'},
#  {'Comment_Id': 'UgzmAYKxdGAblE79vcJ4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'But kadal enn blueva irukku?adha sollamudiyuma Sam.',
#   'Comment_Author': '@deepanchakravarthy2263',
#   'Comment_Published': '2024-02-28T03:57:57Z'},
#  {'Comment_Id': 'UgwGBiy1n42P-VG9Ef94AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'pls talk about Tesla number 3,6,9',
#   'Comment_Author': '@kuttysathish8675',
#   'Comment_Published': '2024-02-28T03:54:14Z'},
#  {'Comment_Id': 'UgxgJyhvhvhOm51Fvfd4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'LMES , Mr Gk வரிசையில் இப்போது<br>Science With Sam 🔥🔥🔥',
#   'Comment_Author': '@prabanjan.pkavaskar.p7449',
#   'Comment_Published': '2024-02-28T03:45:04Z'},
#  {'Comment_Id': 'UgyDtQ6caVKJ0Mp9ioh4AaABAg',
#   'Video_Id': 'yksgUtc4F5M',
#   'Comment_Text': 'Ss squad👽✨',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2024-02-28T03:31:42Z'},
#  {'Comment_Id': 'UgxQDJNsQUZvShCmqxJ4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Schrodinger part 4 ? Na',
#   'Comment_Author': '@karthickeyan6603',
#   'Comment_Published': '2024-02-28T06:56:01Z'},
#  {'Comment_Id': 'UgygYWYQSOZs2zjj7XZ4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': '🎉🎉🎉',
#   'Comment_Author': '@karthickeyan6603',
#   'Comment_Published': '2024-02-17T01:13:35Z'},
#  {'Comment_Id': 'Ugz8hqRDfeaQ2uNh9jp4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Sir cat theory',
#   'Comment_Author': '@gopaluu3569',
#   'Comment_Published': '2024-02-15T19:39:36Z'},
#  {'Comment_Id': 'UgzAneU3Bo5Fx674rNR4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Sir keep uploading i almost watched all your videos',
#   'Comment_Author': '@gopaluu3569',
#   'Comment_Published': '2024-02-15T19:28:24Z'},
#  {'Comment_Id': 'UgxEX7tM9wLn97-H5pF4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Sir pls you hear thiruvasagam in anda paguthi song that song have science based one so what is your opinion or idea oru video poduga',
#   'Comment_Author': '@sivaraj4754',
#   'Comment_Published': '2024-02-15T15:16:40Z'},
#  {'Comment_Id': 'Ugw2L4tQds7rdkHTk994AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Ss squad👽✨',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2024-02-15T09:01:49Z'},
#  {'Comment_Id': 'UgzArZ72HNBLVOYH4Gd4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'According to the cosmological principle, the universe looks the same everywhere because space is isotropic and homogeneous, which means one direction in space is identical or equivalent to any other direction. If so, then when we measure a receding galaxy from us at any point in the universe, we might get the same result about the expansion of the universe as our milky way. If two observers measured the expansion of the universe at two separate points, what kind of results would they get? Does it cause discrepancies in measurement??',
#   'Comment_Author': '@selvakumar-nr4ir',
#   'Comment_Published': '2024-02-15T04:27:12Z'},
#  {'Comment_Id': 'UgxMVEUE86q7FV0ElUR4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'கடந்த  நிகழ்வுகளை தற்கால நிகழ்வுகளுடன் ஒப்பிட்டு  சொல்வது சுவாரசியம் .....for example விவசாயிகள் போராட்டம்...\r<br>\r<br>This capacity for linking ideas is more crucial for scientists, creators, or lateral thinkers, There&#39;s a miniature scientist hidden within Sam&#39;s mind.',
#   'Comment_Author': '@aruranganeshan2951',
#   'Comment_Published': '2024-02-14T23:05:40Z'},
#  {'Comment_Id': 'UgxL2DGn6GkOGqDQr_x4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': '🎉 superb narration. வாழ்த்துக்கள் 🎇',
#   'Comment_Author': '@balasubramaniamv.s.7778',
#   'Comment_Published': '2024-02-14T18:50:18Z'},
#  {'Comment_Id': 'Ugyt3D8BqwUJWLCnd3t4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'People must appreciate his work',
#   'Comment_Author': '@stalinr2171',
#   'Comment_Published': '2024-02-14T17:34:06Z'},
#  {'Comment_Id': 'Ugym8G-j81eFN14Vi2V4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Dr. Sam.. can you please talk about Kramer - Kronig relation from very basic to apply in electromagnetic materials, it will so much helpful for me to learn from you since you are also working in light-matter interaction. This is my humble request, please consider it. Thank you.',
#   'Comment_Author': '@Arunkumar-rg4sr',
#   'Comment_Published': '2024-02-14T16:51:50Z'},
#  {'Comment_Id': 'Ugzbu1893SoSVW2sPXF4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Just knowledge doesn&#39;t fullfill our life, courage and acceptance are essential part of life to anyone.',
#   'Comment_Author': '@kaliraj9901',
#   'Comment_Published': '2024-02-14T16:46:27Z'},
#  {'Comment_Id': 'UgwxyomLtpkpCemeWO94AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Sir,Why you not share your replay message to me about my concept .it makes a kind of  regret to me and if I made some disturbance to you , please forgive me through this comment and send your replay about my concept , what ever it is like correct or wrong I definitely accept your replay even it is wrong ,but please share your reply message to me about my all entire concept in this single comment if you share your replay message in this comment not like give some like / heart from your YouTube channel by you but like the reply message in the form of declarative , then I will become happy when I read your replay message so please   gives some reply message to me about my concept',
#   'Comment_Author': '@dhanasegarandhanush2494',
#   'Comment_Published': '2024-02-14T15:10:29Z'},
#  {'Comment_Id': 'Ugy5qG7kQcevd1HYNrt4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Where are you working now?',
#   'Comment_Author': '@seetharamanslm3234',
#   'Comment_Published': '2024-02-14T14:59:12Z'},
#  {'Comment_Id': 'UgwlOACyTAtMqfihKTh4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Bro Dr apj  abdhul kalam  story ithu mathri detaila sollunga bro',
#   'Comment_Author': '@trollboy7709',
#   'Comment_Published': '2024-02-14T14:55:22Z'},
#  {'Comment_Id': 'UgyvV_uReu_XNfsyAiJ4AaABAg',
#   'Video_Id': 'GW7tQGoQSMA',
#   'Comment_Text': 'Thanks',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-02-14T14:50:33Z'},
#  {'Comment_Id': 'Ugw27GZhL90cLj49cbV4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Nice work sir',
#   'Comment_Author': '@stalinr2171',
#   'Comment_Published': '2024-02-14T17:49:30Z'},
#  {'Comment_Id': 'Ugy0d6qS64lnyTcUix54AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Super bro.. awaiting next episode',
#   'Comment_Author': '@zenguna',
#   'Comment_Published': '2024-02-13T11:21:15Z'},
#  {'Comment_Id': 'UgxEeldIkNU3k3Yn95B4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Thanks Sam.. I hope you shall think about a series of Boltzmann!!',
#   'Comment_Author': '@kannadassasn',
#   'Comment_Published': '2024-02-12T04:00:08Z'},
#  {'Comment_Id': 'UgztU0EftDKPGnO6wj94AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'When I watch your videos I really amazed that I have to know many things that I don&#39;t know. I&#39;m just 17 years old but I can understand your teaching very clearly',
#   'Comment_Author': '@HinafAhamed',
#   'Comment_Published': '2024-02-10T10:49:30Z'},
#  {'Comment_Id': 'UgyHmfPcGaW0OJOOVMh4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'talk about Tesla number anna pls',
#   'Comment_Author': '@kuttysathish8675',
#   'Comment_Published': '2024-02-09T19:04:25Z'},
#  {'Comment_Id': 'UgxOj14U-bPA-g8ZlOl4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Jesus is the king of kings 3<br>Jesus bless your family Sir',
#   'Comment_Author': '@Saravanan-xz1dv',
#   'Comment_Published': '2024-02-09T11:53:50Z'},
#  {'Comment_Id': 'UgxRMPzqtceah3DRbH94AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Nice sir',
#   'Comment_Author': '@mouserider6133',
#   'Comment_Published': '2024-02-09T02:29:02Z'},
#  {'Comment_Id': 'UgznA6v5Bp52wprTMTR4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Cathode ray explanation',
#   'Comment_Author': '@pradeep517',
#   'Comment_Published': '2024-02-08T19:26:23Z'},
#  {'Comment_Id': 'Ugz1GDOagajZ0jQzSw94AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': '❤❤🎉 well come anna',
#   'Comment_Author': '@risheerox8755',
#   'Comment_Published': '2024-02-08T18:55:36Z'},
#  {'Comment_Id': 'UgwigUm-9yDPka9lSMt4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Sir I requested you to see my previous comment in the video of &quot; Erwin schordiger part 1&quot; in that comment I told about the clear thought of my first concept so I want from you to go and see my comment and then give some comments by You about my concept it is my humble request please please please 😢😢😢accept it, and also give a reply of whether my concept is correct or wrong<br><br><br>Before you see my previous comment I want to introduce one concept that is the inverse proportionality concept of mc²and hf energies in this case if the mc² is inversaly proportional to hf then one of the coefficient is need to equal the equation it is denote as (β+1)it can be expressed as <br>            <br>           mc² is inversaly proportional to hf then <br>          mc²= (β+1)/hf<br>For the value of β+1 then the eq is changed as <br>         mc²×hf=(β+1)<br>h=mvL as per the de broglie eq then  <br>        mc²×mvL×f=(β+1)<br>V=l×f as lambda ×frequency  then <br>       m²v×vc²=β+1=m²v²c²<br>Therefore the coefficient is <br>      (β+1)=(mcv)² <br>By its dimensions eq (ML²/T²)² we concluded that it is one of the energy but it act as a coefficient in this concept. <br>And by this concept l can rewrite or express a new wave nature like de-broglie <br>Let derivation for the wave nature is <br>          <br>                (β+1)=(mcv)²<br>                (β+1)=((h/L×v)cV)²as by the de-broglie eq<br>                (β+1)=((h/L)c)² for the value of lambda is<br>                1/L²=(β+1)/h²c² then <br>                   L²=(hc)²/β+1 as taking square on both sides for L is  <br>                  L=hc/√(β+1)<br>From the above eq was multiple by c/c then <br>                 L= hc²/c√(β+1)<br>And the above eq is multiple by p/p=mv/mv then <br>                L=hc²×mv/mvc×√(β+1)<br>For the value of β+1=(mvc)²sub in L then <br>                  L=hc²mv/(β+1)<br>                  L =(hc²)p/(β+1)<br>The above eq implise that the lambda is inversaly proportional to coefficient of energy and directly proportional to p=mv which need to equal this eq I use my constant hc²will required. this wave nature will occur when the two energies were inversaly proportional to each other. This is the another point view of wave nature was I supposed and sir,give the reply for what you rate about this concept like it is worth or not .this concept was made in my point of view and it may be exists in reality or not exist .',
#   'Comment_Author': '@dhanasekaran2491',
#   'Comment_Published': '2024-02-08T17:45:50Z'},
#  {'Comment_Id': 'UgxHDQTW-q8ZI-osXYN4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'I’d love to watch your videos and amount of efforts you put in. Please upload videos regularly, Thank you.',
#   'Comment_Author': '@Arunkumar-rg4sr',
#   'Comment_Published': '2024-02-08T16:04:02Z'},
#  {'Comment_Id': 'Ugy9V63iH4Ap0cFe04J4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'How to become a scientist video pooduga',
#   'Comment_Author': '@doctorstrange5462',
#   'Comment_Published': '2024-02-08T15:23:57Z'},
#  {'Comment_Id': 'UgzOEmqYysqY1I6qq1p4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Great work.....keep going sir',
#   'Comment_Author': '@gomathymuthupandi780',
#   'Comment_Published': '2024-02-08T14:56:04Z'},
#  {'Comment_Id': 'Ugx7bub7JE4KlIKYMJd4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Thanks sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-02-08T14:17:18Z'},
#  {'Comment_Id': 'UgzmGnI5UHLt0baQ0Vx4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Schrodinger இன் பூனை... புலியாக மாறி வேகம் எடுத்த மாதிரி.... 2 நாட்களுக்குள் அடுத்த பதிவு ..... Good work',
#   'Comment_Author': '@aruranganeshan2951',
#   'Comment_Published': '2024-02-08T13:32:13Z'},
#  {'Comment_Id': 'UgxPVJAHPgvC8-rYQ4R4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Keeping going sir, interesting series....',
#   'Comment_Author': '@thangarajm2093',
#   'Comment_Published': '2024-02-08T12:58:24Z'},
#  {'Comment_Id': 'UgyUSv-WMranU9H_ZQV4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'Good work🎉',
#   'Comment_Author': '@nandhakumare9392',
#   'Comment_Published': '2024-02-08T12:35:08Z'},
#  {'Comment_Id': 'UgzVRgpzzoj-ctS-0tZ4AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'First comment 🎉',
#   'Comment_Author': '@lakshmananm2500',
#   'Comment_Published': '2024-02-08T12:32:42Z'},
#  {'Comment_Id': 'Ugyy9gPnCc70iUFmBv94AaABAg',
#   'Video_Id': 'K5OoR-Uo7xM',
#   'Comment_Text': 'பயன் உள்ள தகவல் நன்றி🎉',
#   'Comment_Author': '@g.isaacrajasingh1437',
#   'Comment_Published': '2024-02-08T12:32:42Z'},
#  {'Comment_Id': 'UgxPPn1eSI-PFBwR0ZN4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@user-pd3rc5ph7x',
#   'Comment_Published': '2024-03-21T04:08:16Z'},
#  {'Comment_Id': 'Ugw8nJ6gM1OP7guIGjZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Beautiful start of the year - series',
#   'Comment_Author': '@thamaraiblr1605',
#   'Comment_Published': '2024-02-13T14:30:44Z'},
#  {'Comment_Id': 'UgwlwJ5XyS8J42buXll4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': '🕵️At last, there is a video. Nice to meet you again sir. All scientist life&#39;s affected by world war 1 and 2, mostly jew scientist.',
#   'Comment_Author': '@kaliraj9901',
#   'Comment_Published': '2024-02-07T10:36:31Z'},
#  {'Comment_Id': 'Ugz8xN25kL6KyBmlEJ94AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Thank you.',
#   'Comment_Author': '@babupriya8814',
#   'Comment_Published': '2024-02-07T04:04:27Z'},
#  {'Comment_Id': 'UgzBB7vVVLbmh2FADNp4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'தரமானவராக இருந்தாலும் உங்களுக்கு விளம்பரம் இல்லை, x ல் கணக்குத் தொடங்கி youtube linkயை அனுப்பலாம். பெருமாபாலான youtubers அதை செய்கிறார்கள்.. உங்களை நான் youtuber ஆக கருதவில்லை...',
#   'Comment_Author': '@kandasamys8994',
#   'Comment_Published': '2024-02-07T03:02:37Z'},
#  {'Comment_Id': 'UgwQdw7rmuh37cUxMXp4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Hi, sir I was forget to share my comment to you, in this comment I wanted to tell my conclusion about my first concept of energy <br>                   <br>E inversaly proportional to a new term velocity x lambda<br><br>          E = K/V×L.......<br>Where K is such constant exist and L is wave nature (lambda)<br> <br>Sir, I was apologize to see the constant K had a special constant when the energy E is equal to mc² through my equation there is need not to apologize when the Energy is taken like hf, 1/2mv²,mgh, so on  they will provide the constant of normal but we need to apologize for when the energy is taken as mc² will provide a constant of hc² which is denote as omega or Dhanush constant <br><br>Different between the derivation of hf through my eq<br>         <br>           E=K/V×L...... 1<br>We know the dimension formula for all therefore <br>           K=ML²/T²×L/T×L<br>           K=ML^4T^-3 ...2<br>           E=hf therefore ... ..3<br>           E=hf=K/V×L<br>           K=hf×V×L ......4<br>Therefore <br>           K=hv² this is the constant for the eq.......5<br><br>Let the derivation of mc²through my eq <br>                 <br>           E=mc²........ Einstein energy <br>           E=K/V×L........ My point of view <br>If einstein energy is equal to my energy  therfore<br>             <br>           mc²=K/V×L <br>For the constant value therefore <br>           K=mc²×V×L <br>L=h/mv is the de-broglie eq sub in K therefore <br>           K=(mvL)c²<br>           K=(mvh/mv)c²as cancelled the m&amp;v in both numerator and denominator we will got <br>          K=hc².......this new constant will exist in the equation  therefore the equation is written as <br>         E=hc²/V×L........ 6<br>Sir I don&#39;t know this eq is truly exists in real life and this constant is true or not i try to play with the physics by mathematics and equation I was enjoying to play with it  even I n&#39;t consider it is correct  or wrong but by the equation I can definitely said one like that the proportionality concept of mc²and hf  through my eq  <br>By the eq 6<br>            E=hc²/vL <br>Where v=L×f=lambda×frequency<br>Therefore lambda =V/frequency sub it in eq6<br>Therefore  <br>            E=hc²/V×V/f <br>By reciprocal this we got that <br>            E=hf(c²/v²).....<br>            E=mc² therefore <br>            mc²=hf(c²/v²) <br>Therefore the above eq impiles that the mc² is equal to the multiple of hf and (c²/v²) it  denotes that the mc²is directly proportional to hf for objects and for light is mc²=hf due to v=c therefor (c²/v²)=1 by (c²/(v²=c²))=(c²/c²) this is the enough of topic about my concept. In next video I will bring about the concept of another proportionality concept of energy until I wait for your another video...., and sir what are you think about my concept  whether it is worth or not please please please please please please please please please please please 😢 give some reply message  Thank your sir',
#   'Comment_Author': '@dhanasekaran2491',
#   'Comment_Published': '2024-02-06T19:14:47Z'},
#  {'Comment_Id': 'UgyalFudPXqRfXtYwxN4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Thank you sir ❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-02-06T16:57:27Z'},
#  {'Comment_Id': 'UgxB_oXkJ3P4yDijLzt4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Best  best......teacher',
#   'Comment_Author': '@rameeevk4470',
#   'Comment_Published': '2024-02-06T16:41:52Z'},
#  {'Comment_Id': 'Ugw84R3bJBkK9qsNTrZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=QkPhSjo7nsI&amp;t=134">2:14</a>',
#   'Comment_Author': '@krishnaraoragavendran7592',
#   'Comment_Published': '2024-02-06T15:56:20Z'},
#  {'Comment_Id': 'Ugza3SipyGfp8zX2Q4d4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'awaiting eagerly',
#   'Comment_Author': '@jasvanthikams6234',
#   'Comment_Published': '2024-02-06T15:38:18Z'},
#  {'Comment_Id': 'Ugzu9oZBnPpBZ7bKGyZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Great to see you again sam. How is your job going.. How about your research works... Please let us know in your next video...',
#   'Comment_Author': '@kircyclone',
#   'Comment_Published': '2024-02-06T14:34:54Z'},
#  {'Comment_Id': 'UgzCTY4FzspWB3Mo6Kt4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Sam brother you should become Prime Minister since you have better knowledge and understanding, education plays an important role in a nation&#39;s welfare, you will surely lead the nation in a better way, you hold knowledge in both science and mathematics which are more than enough to handle the every situation by multiplying the information provided by the aforementioned things, combining them will get the dynamism to vanquish the issues that a nation faces, I am happiest and proudest to be a part of your system, I am thankful to you forever Sam brother🇬🇧🙏❤👍🇬🇧🙏❤👍',
#   'Comment_Author': '@88INFINITYME88',
#   'Comment_Published': '2024-02-06T09:40:50Z'},
#  {'Comment_Id': 'UgySrsHKtME514IfaUB4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'என்னங்க சகோ....<br>ஏன்! நீண்ட இடைவெளி....?!',
#   'Comment_Author': '@sundharesanps9752',
#   'Comment_Published': '2024-02-06T09:13:46Z'},
#  {'Comment_Id': 'UgxGqW3GcGcM6mhqUvV4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Thank you sir 🙏',
#   'Comment_Author': '@indumathik6108',
#   'Comment_Published': '2024-02-06T02:27:16Z'},
#  {'Comment_Id': 'UgzOb3fyFsmcXRBdAOZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'உங்க வீடியோ விற்கு காத்திருந்து இப்போ தான் வந்திருக்கு😅😅',
#   'Comment_Author': '@rajendiran6451',
#   'Comment_Published': '2024-02-06T01:13:43Z'},
#  {'Comment_Id': 'UgxKQ43nMsOy4lojvHN4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Sam இன்  வருகையும்... அவர் வீடியோ upload பண்ணும் காலமும்... ஒரு &quot;நிச்சயமற்ற&quot;  நிகழ்வுகள்  Schrodinger தத்துவம் போல ....!!!!',
#   'Comment_Author': '@aruranganeshan2951',
#   'Comment_Published': '2024-02-05T21:28:51Z'},
#  {'Comment_Id': 'UgzdM7YjOG_j5HxkmP94AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': '🤝',
#   'Comment_Author': '@saravanank3204',
#   'Comment_Published': '2024-02-05T20:15:07Z'},
#  {'Comment_Id': 'Ugxeg2vf6ZAvfKMd8kd4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Anna daily video poduga plz',
#   'Comment_Author': '@anandraj3481',
#   'Comment_Published': '2024-02-05T18:26:01Z'},
#  {'Comment_Id': 'UgzRcr17cMdtAHPUDkF4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Nice sir',
#   'Comment_Author': '@user-zq4yh1um2h',
#   'Comment_Published': '2024-02-05T17:04:18Z'},
#  {'Comment_Id': 'Ugzi6S3tCrYxd_2HwWF4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'What sir why this gap...',
#   'Comment_Author': '@pichikalokesh2078',
#   'Comment_Published': '2024-02-05T16:31:29Z'},
#  {'Comment_Id': 'UgxGZQ5QAeMRyq3tgdN4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'ஐயா என்னை போல்தான்(என் பெயர் இராமலிங்கம் இது என் மகள் போன் )தினம் தினம் பார்வையாளர்கள் உங்களது வீடியோவை தேடி தேடி பார்த்து ஏமாந்து  விரக்தியால் அமைதியாக இருப்பார்கள் என நினைக்கிறேன் (பார்வையாளர்கள் குறைய வாய்ப்புகள் இருக்க முடியாது )(தொடந்து வீடியோக்கள் போடுங்கள் அய்யா',
#   'Comment_Author': '@aswarthiniramalingam7298',
#   'Comment_Published': '2024-02-05T16:27:23Z'},
#  {'Comment_Id': 'UgwcMtbskx-ZhpOmcdd4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Welcome sir, most expected series...',
#   'Comment_Author': '@thangarajm2093',
#   'Comment_Published': '2024-02-05T16:22:15Z'},
#  {'Comment_Id': 'Ugwmi6m85KF3lIGYipB4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Welcome back Sir❤🎉',
#   'Comment_Author': '@karankaran4427',
#   'Comment_Published': '2024-02-05T16:17:19Z'},
#  {'Comment_Id': 'UgzXCrXAcKLfOQo9VIZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': '❤❤❤❤❤❤❤❤super <br>I am studying <a href="http://m.sc/">M.Sc</a> physics ✅🚩',
#   'Comment_Author': '@imanorakesh6155',
#   'Comment_Published': '2024-02-05T15:55:48Z'},
#  {'Comment_Id': 'Ugy-IMn9spd3fn11bqh4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Welcome back sir🎉🎉🎉u have chosen an interesting topic...waiting for more',
#   'Comment_Author': '@padhoo1973',
#   'Comment_Published': '2024-02-05T15:49:34Z'},
#  {'Comment_Id': 'Ugy0KBV4ZDYKniJOfBp4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@pradeep517',
#   'Comment_Published': '2024-02-05T15:32:40Z'},
#  {'Comment_Id': 'UgxcghKd-sEguKFRjWF4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Hi sir welcome back 🎉',
#   'Comment_Author': '@ilayabharathi1329',
#   'Comment_Published': '2024-02-05T15:26:04Z'},
#  {'Comment_Id': 'UgwX-PuK8Rzy3YwRzaZ4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'இன்னும் இன்னும் எதிர்பார்க்கிறோம் sir எங்கள் அறிவியல் பசிக்கு தீனி போடுங்கள் ❤️❤️',
#   'Comment_Author': '@ARoshanmegal',
#   'Comment_Published': '2024-02-05T15:25:50Z'},
#  {'Comment_Id': 'UgzMQ3S1qfmmiCIExdR4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Good to c u again thank you for sharing your experience',
#   'Comment_Author': '@sureshthsngsrsjsn',
#   'Comment_Published': '2024-02-05T15:08:12Z'},
#  {'Comment_Id': 'Ugztpi_Ua28gsPc16yh4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Upload more class🙎',
#   'Comment_Author': '@edisonkanni8557',
#   'Comment_Published': '2024-02-05T14:53:42Z'},
#  {'Comment_Id': 'UgzmCeCViRJwSfbG7zd4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'அண்ணா தொடர்ந்து வீடியோ போடுங்க உங்க வீடியோ மூலம் நான் உலகை தெளிவாக புரிந்து கொண்டேன்',
#   'Comment_Author': '@Tamiltalaiva',
#   'Comment_Published': '2024-02-05T14:53:18Z'},
#  {'Comment_Id': 'UgznsfvPP78rVsPVB9h4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'welcome back bro .. pls post atleast one video per month',
#   'Comment_Author': '@sampathtlc',
#   'Comment_Published': '2024-02-05T14:43:17Z'},
#  {'Comment_Id': 'UgwFF_amtFxpR7QRzWp4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Sir your amazing,,keep rocking sir🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉',
#   'Comment_Author': '@JepaStepy',
#   'Comment_Published': '2024-02-05T14:29:42Z'},
#  {'Comment_Id': 'Ugyju2G25k5q2Aq1L5R4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Bro subrahmanyan Chandrashekhar avaroda biography solanga bro',
#   'Comment_Author': '@trollboy7709',
#   'Comment_Published': '2024-02-05T14:22:11Z'},
#  {'Comment_Id': 'UgwQQiY_QhALAtx0JWR4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'நீங்க இந்தியா வந்த பிறகு வீடியோ போடுவது குறைந்துவிட்டது தோழரே. உங்களுக்கு வாழ்த்துக்கள் 🌹🌹🌹🙏',
#   'Comment_Author': '@DravidaTamilanC',
#   'Comment_Published': '2024-02-05T14:14:48Z'},
#  {'Comment_Id': 'UgyfCzLlPn52x0O31yR4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'bro edward tellar pathi podunga, i inspired by him when i saw oppenheimer movie ⚡',
#   'Comment_Author': '@karthikkeyansmk2727',
#   'Comment_Published': '2024-02-05T14:14:04Z'},
#  {'Comment_Id': 'UgxBajhXQPxmklfVqmR4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Regular a video podunga bro... I have been learning a lot of things about quantum mechanics from you... And it&#39;s very useful for me... <br><br>This is my kind and humble request to you bro.... Because there is no quantum mechanics or equation available in the Tamil YouTube platform.',
#   'Comment_Author': '@user-tb7hp5bj5m',
#   'Comment_Published': '2024-02-05T14:13:57Z'},
#  {'Comment_Id': 'UgyTF91Qa3K7bCpwX6p4AaABAg',
#   'Video_Id': 'QkPhSjo7nsI',
#   'Comment_Text': 'Neraya video potunga anna',
#   'Comment_Author': '@PHC-ib3xd',
#   'Comment_Published': '2024-02-05T14:06:37Z'},
#  {'Comment_Id': 'UgxtvNG1Z2LRVQVbCWp4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations 👏',
#   'Comment_Author': '@sreehome4699',
#   'Comment_Published': '2024-04-12T00:23:54Z'},
#  {'Comment_Id': 'UgybyvJ-MnEvU6g8Eo94AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'super annaaa',
#   'Comment_Author': '@alavudheenraja3029',
#   'Comment_Published': '2024-03-19T18:01:19Z'},
#  {'Comment_Id': 'Ugy-facRTVzOhOU4iW94AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள் தோழர் 🎉❤<br>தொடர்ந்து அறிவியலை பேசுவோம்.<br>அறிவியல் வயப்படுவோம்!',
#   'Comment_Author': '@rajaraasa492',
#   'Comment_Published': '2024-03-02T10:05:54Z'},
#  {'Comment_Id': 'UgwOmMkl0MLX-APFxat4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations Sir',
#   'Comment_Author': '@rajendranponraman6985',
#   'Comment_Published': '2024-02-08T16:15:39Z'},
#  {'Comment_Id': 'Ugxl395q9p13ZgYa3754AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Sam brother you should become Prime Minister since you have better knowledge and understanding, education plays an important role in a nation&#39;s welfare, you will surely lead the nation in a better way, you hold knowledge in both science and mathematics which are more than enough to handle the every situation by multiplying the information provided by the aforementioned things, combining them will get the dynamism to vanquish the issues that a nation faces, I am happiest and proudest to be a part of your system, I am thankful to you forever Sam brother🇬🇧🙏❤👍🇬🇧🙏❤👍',
#   'Comment_Author': '@88INFINITYME88',
#   'Comment_Published': '2024-02-06T09:39:34Z'},
#  {'Comment_Id': 'UgyrcJBsifC0_gIEfn54AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் தோழர்@வாழ்த்துக்கள் தோழர்@@வாழ்த்துக்கள் தோழர்',
#   'Comment_Author': '@user-lx2bf8tb4s',
#   'Comment_Published': '2024-02-06T00:59:00Z'},
#  {'Comment_Id': 'UgyiGMKxJVu9sBgiokB4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=B-fB9YOM9UE">https://youtu.be/B-fB9YOM9UE?si=E_I8K3RNI7_pdHn8</a>   @    வாழ்த்துக்கள் தோழர்',
#   'Comment_Author': '@user-lx2bf8tb4s',
#   'Comment_Published': '2024-02-06T00:58:04Z'},
#  {'Comment_Id': 'UgyPxU_bD381UlbSUiF4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Sir, I want one video for Quantum computer..',
#   'Comment_Author': '@SeeniVasan-ri1wk',
#   'Comment_Published': '2024-02-01T11:23:30Z'},
#  {'Comment_Id': 'UgzEwCoXoLOE6f6F0y94AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Sir thodarthu video podunge',
#   'Comment_Author': '@zeerah995',
#   'Comment_Published': '2024-01-28T15:07:24Z'},
#  {'Comment_Id': 'Ugwlr90Y0JkoPTRJRtR4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் அண்ணா...',
#   'Comment_Author': '@user-ef5fv1do9r',
#   'Comment_Published': '2024-01-26T14:04:53Z'},
#  {'Comment_Id': 'UgyinarBTgbFW22rciR4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'I have watched a video that shows how a space-time should curve. In 2D video it&#39;s curve around a object but in 3D video it&#39;s curve towards a centre of object, which one is right?',
#   'Comment_Author': '@seenivasanadsk7868',
#   'Comment_Published': '2024-01-25T17:43:59Z'},
#  {'Comment_Id': 'UgyJvVohbW1NlTaWXbx4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Sam அண்ணா இந்த விருதை வாங்குவதற்கு தகுதி வாய்ந்தவர் நீங்கள் ஒருவரே தமிழகத்தில்.... God Bless You sam அண்ணா..... 💞🥰😍 தங்களை போல் எங்களுக்கு அறிவியல் கற்று  தர யாரும் கிடைக்க வில்லை நான் பயின்ற பள்ளியில்.... உங்கள் மாணவர்கள் அனைவரும் உங்களை போல் வளர நான் கடவுளிடம் வேண்டிக்கொள்கிறேன் 💞.... உங்களின் உழைப்பிக்கு கிடைத்த விருது Sam Brother ....thanks for KPR College 🫂',
#   'Comment_Author': '@spartanmani2228',
#   'Comment_Published': '2024-01-24T17:36:56Z'},
#  {'Comment_Id': 'Ugxb_lg1f4vjnBcKTg14AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Most loved channel ❤',
#   'Comment_Author': '@sankarr1080',
#   'Comment_Published': '2024-01-24T17:14:08Z'},
#  {'Comment_Id': 'UgzgihCLRI7DHaZoBcl4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள்',
#   'Comment_Author': '@nageswarankalimuthu6333',
#   'Comment_Published': '2024-01-23T16:00:12Z'},
#  {'Comment_Id': 'Ugz7geW9llJkILg4h-R4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'I would have more happy if I meet you in person sir. Anyway I&#39;m also really happy for u. You deserve this for ur efforts. We always support you. Thank you for making efforts sir 🎉',
#   'Comment_Author': '@indumathik6108',
#   'Comment_Published': '2024-01-20T15:23:33Z'},
#  {'Comment_Id': 'UgyQ7W5yrznF9NHCXdJ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations guru',
#   'Comment_Author': '@prabhua8787',
#   'Comment_Published': '2024-01-15T09:18:45Z'},
#  {'Comment_Id': 'Ugzs0VupcspCjnMFvjB4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': '❤🎉❤',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2024-01-14T21:55:15Z'},
#  {'Comment_Id': 'UgzZvv1CRq4SI4DR7x94AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations sir ❤❤',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2024-01-14T03:01:56Z'},
#  {'Comment_Id': 'UgzPFuJR6wVPkVc8qCZ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Jesus bless your family 3<br>Super sir 🙏 👏 🙌 <br>Jesus never fails 🙌 🙏',
#   'Comment_Author': '@Saravanan-xz1dv',
#   'Comment_Published': '2024-01-12T05:16:58Z'},
#  {'Comment_Id': 'UgzfrvYhxgVwKgh3dTt4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'நீங்கள் தொடர்ந்து பேசுங்கள் எங்கள் அறிவு  வளர',
#   'Comment_Author': '@ramalingamk826',
#   'Comment_Published': '2024-01-12T00:49:29Z'},
#  {'Comment_Id': 'UgwUuTCPPlmM5Y2Isgx4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': '🎉🎉Congratulations 🎉🎉...  Proud moment 🎉',
#   'Comment_Author': '@thamaraiblr1605',
#   'Comment_Published': '2024-01-11T17:40:06Z'},
#  {'Comment_Id': 'UgyXQaId05OXxcF5Ldh4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Friend. You  deserve that.',
#   'Comment_Author': '@chakrapanikrishnanchakrapa2527',
#   'Comment_Published': '2024-01-11T14:19:23Z'},
#  {'Comment_Id': 'Ugzd0tse364geTlQ5At4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations Sir ur are speaking at simplicity and ur hardwork will give so many success ✨',
#   'Comment_Author': '@sakthi9920',
#   'Comment_Published': '2024-01-11T13:40:01Z'},
#  {'Comment_Id': 'UgxN2BcaPVF2LoTrVLl4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations,all  your hard work brings this award 👏',
#   'Comment_Author': '@hemalathadevi5448',
#   'Comment_Published': '2024-01-11T13:35:37Z'},
#  {'Comment_Id': 'Ugw-eK2T-HIkCWasM654AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congrats n best wishes',
#   'Comment_Author': '@balasubramanian1039',
#   'Comment_Published': '2024-01-11T11:19:22Z'},
#  {'Comment_Id': 'UgyTv9n3-4pOa2LQZbh4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Super bro',
#   'Comment_Author': '@shyamdeva4140',
#   'Comment_Published': '2024-01-11T09:17:23Z'},
#  {'Comment_Id': 'UgwCTBOGmEzuqoR88BJ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Heartily congratulations bro, u have way ahead in the journey of science.',
#   'Comment_Author': '@karthik23839',
#   'Comment_Published': '2024-01-11T06:48:53Z'},
#  {'Comment_Id': 'UgyeXL2O7ayuzOK0C2B4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Super anna ❤ congratulations 🎉',
#   'Comment_Author': '@mrgoats8474',
#   'Comment_Published': '2024-01-11T05:19:54Z'},
#  {'Comment_Id': 'Ugy0mQJAy4MATZMD3CZ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations bro !!',
#   'Comment_Author': '@prabhusteve7258',
#   'Comment_Published': '2024-01-11T03:22:38Z'},
#  {'Comment_Id': 'UgxUCGxVoGWFiiLcuK54AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் தம்பி',
#   'Comment_Author': '@user-eo7ge1bz9w',
#   'Comment_Published': '2024-01-11T02:41:06Z'},
#  {'Comment_Id': 'UgzmYvIQcxbVVANQpwZ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'You deserved bro. Please continue to share post atleast weekly once .',
#   'Comment_Author': '@zenguna',
#   'Comment_Published': '2024-01-10T22:04:39Z'},
#  {'Comment_Id': 'UgwJZGG0dq3b6eg-HC94AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'CONGRATULATIONS❤️❤️ SIR',
#   'Comment_Author': '@ARoshanmegal',
#   'Comment_Published': '2024-01-10T14:41:50Z'},
#  {'Comment_Id': 'Ugx8bupEpa3tQpswAGt4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் 🎉🎉🎉',
#   'Comment_Author': '@venkateshponraj6604',
#   'Comment_Published': '2024-01-10T12:34:24Z'},
#  {'Comment_Id': 'UgzcbjsvG3HDWfXBoft4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் சாம் சார் மென்மேலும் வளர்ந்து இது போன்ற பல விருதுகளை பெற என்னுடைய வாழ்த்துக்கள்',
#   'Comment_Author': '@seenuseenu7892',
#   'Comment_Published': '2024-01-10T12:23:54Z'},
#  {'Comment_Id': 'UgyR7SA43qwF5hbKTKp4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations, sir',
#   'Comment_Author': '@Arunkumar-rg4sr',
#   'Comment_Published': '2024-01-10T11:18:02Z'},
#  {'Comment_Id': 'UgwoZpqSukizzVw9Ob14AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:36Z'},
#  {'Comment_Id': 'Ugw5gdVjpiYoSr3z1tB4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:35Z'},
#  {'Comment_Id': 'UgynHtUi631qP_Yggjh4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:35Z'},
#  {'Comment_Id': 'UgzMuBHGbVwWBlbLwnN4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:36Z'},
#  {'Comment_Id': 'UgzD3AIqG0W5gPE3LpF4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:36Z'},
#  {'Comment_Id': 'UgzvhvBqe_PPFVaB4rJ4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:36Z'},
#  {'Comment_Id': 'UgwQ_O2_AxB236r8mNh4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துகள்',
#   'Comment_Author': '@vasanthanjoseph5852',
#   'Comment_Published': '2024-01-10T10:44:36Z'},
#  {'Comment_Id': 'Ugw_NH1ujzEf6GbaG5t4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations thambi',
#   'Comment_Author': '@shanthiumakanthan9991',
#   'Comment_Published': '2024-01-10T10:35:56Z'},
#  {'Comment_Id': 'Ugy7mnoceA-PiN_lpYp4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'மனமார்ந்த வாழ்த்துக்கள்',
#   'Comment_Author': '@kalaiselvan6761',
#   'Comment_Published': '2024-01-10T09:15:41Z'},
#  {'Comment_Id': 'UgzJ05YzhOxoI_u-ArN4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations Anna....you deserve for your work.. we request you to do more videos on unknown science topics. waiting.....',
#   'Comment_Author': '@Manojkumar-ur5do',
#   'Comment_Published': '2024-01-10T07:59:10Z'},
#  {'Comment_Id': 'UgxMLeMSkJDcnCVYYfR4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Vazhthukkal anna Romba happy👍👍👍👍👏👏',
#   'Comment_Author': '@excitingscience3846',
#   'Comment_Published': '2024-01-10T06:55:45Z'},
#  {'Comment_Id': 'UgxNBEi6YApZQW5kTSN4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'congrats brother , keep going with more awards',
#   'Comment_Author': '@ochathevanselvaraj5565',
#   'Comment_Published': '2024-01-10T06:34:58Z'},
#  {'Comment_Id': 'UgwN62FgeVGY6JUcceF4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'Congratulations anna',
#   'Comment_Author': '@nethajikumar3543',
#   'Comment_Published': '2024-01-10T06:30:33Z'},
#  {'Comment_Id': 'UgxE6Rb5t9mxuZ-GpmN4AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'I wish you could post a video at least monthly once. And, Your narration about the science has been magnificent and fabulous.  I have also  been eagerly watching yours. Kindly consider our request and keep posting your videos. I know l, you are quite the busiest professor.',
#   'Comment_Author': '@darrelllyjo9162',
#   'Comment_Published': '2024-01-10T06:05:48Z'},
#  {'Comment_Id': 'UgxaV9eAUSLn78fsRi14AaABAg',
#   'Video_Id': 'pSLahAy8nC4',
#   'Comment_Text': 'வாழ்த்துக்கள் சகோதரர் ❤🎉',
#   'Comment_Author': '@darrelllyjo9162',
#   'Comment_Published': '2024-01-10T05:59:53Z'},
#  {'Comment_Id': 'Ugzb0vpaN8UKcPjx7_R4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Comment_Text': 'Jesus bless your family Sir <br>🎉🎉🎉',
#   'Comment_Author': '@Saravanan-xz1dv',
#   'Comment_Published': '2024-01-18T04:45:40Z'},
#  {'Comment_Id': 'Ugwu778xs8Oix1T39GV4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Comment_Text': 'Happy new year Sam. You are the best science reviewer. Looking forward to expecting more videos from you',
#   'Comment_Author': '@pol_hap9782',
#   'Comment_Published': '2024-01-09T10:09:05Z'},
#  {'Comment_Id': 'UgxG4I7zk2VxCBJ13IJ4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Comment_Text': 'explain the atom zero to advance all like electron spaining stage full topic of atom pls',
#   'Comment_Author': '@electrical24tesla',
#   'Comment_Published': '2024-01-06T15:34:23Z'},
#  {'Comment_Id': 'Ugw-ZkduugbEX89jiQx4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Comment_Text': 'Happy New Year sir',
#   'Comment_Author': '@jacqulin5731',
#   'Comment_Published': '2024-01-04T14:41:47Z'},
#  {'Comment_Id': 'UgzXlVPLIO2-hXrWVNh4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
#   'Comment_Text': 'Please back bro',
#   'Comment_Author': '@magaayya2726',
#   'Comment_Published': '2024-01-04T11:37:56Z'},
#  {'Comment_Id': 'UgzYxU9b-1lrPanBZ4N4AaABAg',
#   'Video_Id': 'JgzEOrPmaDI',
# ...
#   'Comment_Author': '@RajRaj-ii9dn',
#   'Comment_Published': '2023-03-03T04:48:33Z'},
#  {'Comment_Id': 'UgzwfLcCAb9hNCSOHox4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'Science👍<br>Thank you Sam Sir.',
#   'Comment_Author': '@deepanpetervishwajeet2712',
#   'Comment_Published': '2023-03-03T03:13:34Z'},
#  {'Comment_Id': 'UgzkdPL0qHJoCdGjvcR4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'I become fan  of feymann, &quot; Father of Curiosity&quot; , feyman video podunga',
#   'Comment_Author': '@karthikkeyansmk2727',
#   'Comment_Published': '2023-03-03T01:52:11Z'},
#  {'Comment_Id': 'UgxYO-59pg-MW1S63bN4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'Bro feymann video podunga',
#   'Comment_Author': '@karthikkeyansmk2727',
#   'Comment_Published': '2023-03-03T01:51:25Z'},
#  {'Comment_Id': 'UgySv3O537hX2CEKW2h4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'Hi sir follower from srilanka.sir did you see the spacex rocket lunch today(feb.2).and what about the artimse test result pls make the vdo about that i like to watch in your chennal sir',
#   'Comment_Author': '@asmathkhan5075',
#   'Comment_Published': '2023-03-02T19:55:37Z'},
#  {'Comment_Id': 'UgyXudhPvvNw8jf6xrV4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'beneath of mine oru comment irukku adhukku 1000 likes',
#   'Comment_Author': '@kaanth2010',
#   'Comment_Published': '2023-03-02T15:26:37Z'},
#  {'Comment_Id': 'UgwOr23Ub4LtVx1Qlwd4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'Detect pannavangala paarattanum, inga naanga ammai podura saamiya palavarudam thaduppu oosi pottu thadukkurom, but kuzhandhainga safe aagitta piragu marubadiyum madham jaadhi nu kedukkurom. idhu romba jolly ah irukku',
#   'Comment_Author': '@kaanth2010',
#   'Comment_Published': '2023-03-02T15:25:38Z'},
#  {'Comment_Id': 'UgwMRohs14l9df_qrld4AaABAg',
#   'Video_Id': 'KpuRyc00_t0',
#   'Comment_Text': 'First view sir',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2023-03-02T14:46:47Z'},
#  {'Comment_Id': 'Ugxa5SQa3IiQdRgA45R4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Super sam sir 💐💐💐',
#   'Comment_Author': '@jacqulin5731',
#   'Comment_Published': '2023-03-14T16:18:03Z'},
#  {'Comment_Id': 'UgyrDOmTMaIH4IVk0Jl4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '<a href="https://youtu.be/ObaguMglE-Ylow">https://youtu.be/ObaguMglE-Ylow</a> cost Quantum entaclement water spliter to generate clean hydrogen with AAA 1.5 volt battery\r<br>This is different all kind of electrolysis method because input is less than 200 mili volt and external heat is 120 degree Celsius only,using 600°c degree heat resistant and dielectric borosil ceramic container and aluminium porous strip electrode and electrolysing and boiling works at a time in one container and  DC back EMF problem redirect to split water continuously by silicon semiconductor diode\r<br>\r<br>needs of material thermometer multimeter,1.5 volt battery, 100K potential metre,silicon semiconductor diode, aluminium porous strip electrode,100 ml heat resistant and dielectric borosil container,60 ml 1:6 h2so4 dialuted water,LPG gas burner, that&#39;s all\r<br>\r<br>problem and salvation\r<br>number 1 when water boils at 100 degree Celsius it losses its density and goes to zero electric resistance it means zero horms, so it is possible to reduce input voltage as much as possible..\r<br>\r<br>number 2 major problem of the DC back EMF\r<br>why can&#39;t make hydrogen cheaper\r<br>because of the DC back EMF is reason when reducing input voltage the hydrogen and oxygen fuel cells gives and EMF of 0.73 volte and electric current chaseed, this problem can solve by semiconductor diode this technique inverted in 1976 by space scientist yes Venkatesan patent holder of ccw hydrogen engine\r<br>\r<br>எக்ஸ்பெக்டிங் ரிசல்ட் expecting result\r<br>\r<br>Total  input is approximately 80 wats to heat 60 ml H2SO4 1:6 dialuted water\r<br>when splitting the 60 ml water gives approximately seven gram hydrogen 1 gram hydrogen equal to 40 wats,7gram hydrogen equal to 280 watts output is more than input by Quantum entanglement\r<br>total input in the mechanism equal to the total output is produced\r<br>\r<br>points of reference\r<br>number 1\r<br>1889 lordwik mond and corl long   American scientist of gas battery clean hydrogen project \r<br>number 2\r<br>yes Venkatesan in 1976 invented ccw hydrogen engine-reported to NRDC \r<br>\r<br>number 3\r<br>In 2014 the American  Stanford scientist  Hangsitoi and meengank -invented  low cost water splitting-at room&#39;temperature using triple AAA 1.5 battery nikal porus electrode and nickel oxide catalyse etc..\r<br>\r<br>number 4 in 2019 the American brown University scientist invented the  goldylock problem in electrolysis on platinum electrode',
#   'Comment_Author': '@user-lx2bf8tb4s',
#   'Comment_Published': '2023-03-06T15:44:06Z'},
#  {'Comment_Id': 'UgwgvPHmqkSk1nN-3AZ4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '🌈',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-03-03T16:12:19Z'},
#  {'Comment_Id': 'Ugyd84CMhyzV0Aa-vbt4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '🎉❤good news 👏 🙌 👍 🙏 👌 ❤',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-03-03T16:07:38Z'},
#  {'Comment_Id': 'Ugyv7sdFUxJkVrzwJg14AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '🎉❤ good',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-03-03T16:06:47Z'},
#  {'Comment_Id': 'Ugw9VMcR5Rc9m6DFwEV4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '❤🎉',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-03-03T16:06:05Z'},
#  {'Comment_Id': 'UgypBialhz-n-kkvjIt4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': '❤',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-03-03T16:05:44Z'},
#  {'Comment_Id': 'UgwrKRcBcs78LOtGWzB4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'bro feymann series continue poodunga , i am curious',
#   'Comment_Author': '@karthikkeyansmk2727',
#   'Comment_Published': '2023-03-01T15:22:54Z'},
#  {'Comment_Id': 'Ugz-1YW0bypRMB7S_Jd4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'இரவின் தூங்காமல் ரொம்ப கண் விழிக்கிறீர்கள் என்று நினைக்கிறேன். உடம்பை நன்றாக பார்த்துக் கொள்ளுங்கள்.',
#   'Comment_Author': '@ramupattu9444',
#   'Comment_Published': '2023-03-01T09:07:31Z'},
#  {'Comment_Id': 'UgxTpndaUZTZMLjHDll4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Thank you ❤️ sir',
#   'Comment_Author': '@khubaibkhan9625',
#   'Comment_Published': '2023-03-01T02:07:49Z'},
#  {'Comment_Id': 'UgwIy4YsqpBF4FWbuNN4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'மகிழ்ச்சி !!!தேசிய அறிவியல் தின வாழ்த்துக்கள்.!!! நன்றி கள்!!!',
#   'Comment_Author': '@simman275',
#   'Comment_Published': '2023-02-28T18:14:09Z'},
#  {'Comment_Id': 'Ugxx8jSH9pxPcJPfnip4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'LMES , Mr Gk வரிசையில் இப்போது<br>Science With Sam 🔥🔥🔥',
#   'Comment_Author': '@prabanjan.pkavaskar.p7449',
#   'Comment_Published': '2023-02-28T17:30:13Z'},
#  {'Comment_Id': 'UgwC5StMEXQuf5DmIjd4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Sir.  How to join (work) in physics lap ? Plz',
#   'Comment_Author': '@herbart_evans123',
#   'Comment_Published': '2023-02-28T17:07:17Z'},
#  {'Comment_Id': 'UgyQsXyIKdCzTEX9PgV4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Nombanaal kalichi video poduringa 🥺',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2023-02-28T17:05:32Z'},
#  {'Comment_Id': 'Ugzqr_bR9C59qkyL9cR4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Yenga college la kudam condect panna ga Sir',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2023-02-28T17:02:48Z'},
#  {'Comment_Id': 'UgxQu1Yif5AuXpbLn554AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Sir kind request !<br>To continue Richard Feynman series',
#   'Comment_Author': '@anantanarayananr279',
#   'Comment_Published': '2023-02-28T16:55:53Z'},
#  {'Comment_Id': 'UgwpYyPHFVvqTAHwemx4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Happy to see you today sir. Pls sir try to post more videos. Your contents are very worthy.',
#   'Comment_Author': '@river3006',
#   'Comment_Published': '2023-02-28T16:48:46Z'},
#  {'Comment_Id': 'Ugymb4lEMGUe5kqjRWZ4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'தேசிய அறிவியல் தின வாழ்த்துக்கள்.',
#   'Comment_Author': '@deepanpetervishwajeet2712',
#   'Comment_Published': '2023-02-28T16:43:54Z'},
#  {'Comment_Id': 'Ugwa5E739tIxytCm4nN4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Sir plz 3 days ku orukka sari video podunga',
#   'Comment_Author': '@risheerox8755',
#   'Comment_Published': '2023-02-28T16:22:06Z'},
#  {'Comment_Id': 'Ugynd-sWhx6tR7vJdzZ4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Super தம்பி...<br>ராமன் பெயர் அறிவியலிலும்...<br>மற்றபிற இடங்களிலும் நிலைத்திருக்கும்.<br>&quot;ஸ்ரீராமஜெயம்&quot;<br>💙🙏',
#   'Comment_Author': '@scienceknowledge1000',
#   'Comment_Published': '2023-02-28T16:00:37Z'},
#  {'Comment_Id': 'UgyUSqj0V5amIBS88vh4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'வாழ்த்துகள் நண்பா',
#   'Comment_Author': '@sampathtlc',
#   'Comment_Published': '2023-02-28T15:44:11Z'},
#  {'Comment_Id': 'Ugx-Urp2JuD0AqZRa-l4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'மிக்க மகிழ்ச்சி 🙏🙏🙏',
#   'Comment_Author': '@govindasamy1144',
#   'Comment_Published': '2023-02-28T15:41:32Z'},
#  {'Comment_Id': 'UgxHM-08eA8hQcir2qB4AaABAg',
#   'Video_Id': 'E5O7Nx6lpu0',
#   'Comment_Text': 'Ss squad ✨',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2023-02-28T15:40:19Z'},
#  {'Comment_Id': 'UgwxN0DTnnAXXls8kh94AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Welcome back DR',
#   'Comment_Author': '@msbs2087',
#   'Comment_Published': '2023-08-10T12:56:33Z'},
#  {'Comment_Id': 'UgxXvdEdbB3wJ2IJ3Zd4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Yen yoodha makkal adhigamaga scientist ah irukanga.',
#   'Comment_Author': '@yovantensingh4288',
#   'Comment_Published': '2023-04-07T12:44:16Z'},
#  {'Comment_Id': 'Ugz02he-9IhM9Sd6SSJ4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Sir recent ah physics concepts pathi en pesarathilla? Like quantum mechanics, electricity, thermodynamics, relativity and it&#39;s theories. Unga old videos ellam repeat mode pathuttu eruken sir. Please do more videos in basic concepts of physics. It&#39;s so interesting to know and learn physics in your way 😌🤓',
#   'Comment_Author': '@river3006',
#   'Comment_Published': '2023-02-27T07:04:50Z'},
#  {'Comment_Id': 'UgyiEOKYBBp32R2Llet4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'we miss your videos so much anna 😕',
#   'Comment_Author': '@vigneshnivas681',
#   'Comment_Published': '2023-02-26T15:44:45Z'},
#  {'Comment_Id': 'UgyjtvHcKKCa15XfIsR4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Thalaiva enga poningaa',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2023-02-23T10:29:08Z'},
#  {'Comment_Id': 'Ugw9J520e7Jstb_ovrR4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'super 👌 👍 😍',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-02-08T12:55:49Z'},
#  {'Comment_Id': 'UgyGwS1PvY6zafRJRu94AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'super',
#   'Comment_Author': '@sakthikumar0',
#   'Comment_Published': '2023-02-08T11:38:30Z'},
#  {'Comment_Id': 'UgwWCYWWnPmjR0GI5iZ4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Tramandus explanations . May I  know your educational qualification ?',
#   'Comment_Author': '@ts.nathan7786',
#   'Comment_Published': '2023-02-07T15:21:27Z'},
#  {'Comment_Id': 'UgyvkBQ0OKkfwCQ0QyJ4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Sir nitrogen narcosis என்றால் என்ன',
#   'Comment_Author': '@Cuckoo123',
#   'Comment_Published': '2023-02-07T14:33:24Z'},
#  {'Comment_Id': 'UgwOzett9R4f1zJao6Z4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Marconi ya pathi podunga',
#   'Comment_Author': '@AMEENAFRAR',
#   'Comment_Published': '2023-02-07T08:34:03Z'},
#  {'Comment_Id': 'UgwN41NqDCvX76snDMh4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Einstein&#39;s God letter பற்றி காணொளி பதிவிடுங்கள் sam',
#   'Comment_Author': '@udhaykumar2553',
#   'Comment_Published': '2023-02-07T02:07:35Z'},
#  {'Comment_Id': 'Ugy7DuCYCbcQsCLnoS94AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Thaliva  need more videos love from Srilanka',
#   'Comment_Author': '@risheerox8755',
#   'Comment_Published': '2023-02-06T20:05:44Z'},
#  {'Comment_Id': 'UgzQWftmjxeycN_u4dx4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Neega speed sonnalum slow VA sonnalum ,Naa yeppadiyum marupadiyum marupadiyum paapa😊 ,appo tha sir clear aaa purithu',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2023-02-06T18:00:24Z'},
#  {'Comment_Id': 'UgwL4ol-Qa1C-7bLlpl4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'தெளிவான விளக்கம் கொடுத்தீங்க.<br>நன்றி.<br>அடுத்த வீடியோவுக்காக காத்திருக்கும்...<br>அண்ணன்...<br>💙🙏',
#   'Comment_Author': '@scienceknowledge1000',
#   'Comment_Published': '2023-02-06T17:44:04Z'},
#  {'Comment_Id': 'UgwykxQAxgnmGfXUlml4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Thank you Sam Sir<br>Free flow of language <br>Amazing teacher within you',
#   'Comment_Author': '@deepanpetervishwajeet2712',
#   'Comment_Published': '2023-02-06T17:15:33Z'},
#  {'Comment_Id': 'UgzeZIH6cyZbU1yHjzZ4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'bro feymans oda fundamentals of physics YouTube la teach panringaala bro please',
#   'Comment_Author': '@muthukamalan.m6316',
#   'Comment_Published': '2023-02-06T16:59:31Z'},
#  {'Comment_Id': 'UgxvypY2OChT6IotsrF4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Bro feynman diagram and infinite path integral pathi oru brief explanation kudunga bro',
#   'Comment_Author': '@vigneshvivek2719',
#   'Comment_Published': '2023-02-06T16:59:08Z'},
#  {'Comment_Id': 'UgxEPQdeOPMjIheNAwF4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Human age (biology)cel poruthu thana age aagum ,aparam yeppadi Einstein time dialiation saathiyam',
#   'Comment_Author': '@vikramathithan_nj1074',
#   'Comment_Published': '2023-02-06T15:23:08Z'},
#  {'Comment_Id': 'Ugyi7GIQWYC_v7mUDet4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Si r ennku oru dobut. Eppadi eq condupidikarnga',
#   'Comment_Author': '@SuryaPrakash-dj4qc',
#   'Comment_Published': '2023-02-06T14:45:32Z'},
#  {'Comment_Id': 'UgzlCM6CpVODqeNSG_Z4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'I am waiting for this video bro 😆😆',
#   'Comment_Author': '@karunamoorthy_D',
#   'Comment_Published': '2023-02-06T14:45:17Z'},
#  {'Comment_Id': 'UgwNhVKSotDA10eC5954AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Great fynman',
#   'Comment_Author': '@dineshbaskaran3406',
#   'Comment_Published': '2023-02-06T14:07:04Z'},
#  {'Comment_Id': 'UgyUwcffixwclYsI67Z4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Sir..Feynman&#39;s books 3 volumes available in online ...is it good one to buy for beginners to know the fundamental of physics..',
#   'Comment_Author': '@thangarajm2093',
#   'Comment_Published': '2023-02-06T13:52:15Z'},
#  {'Comment_Id': 'UgyWse01_butcJZPrTN4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Super anna 🔥🔥🔥',
#   'Comment_Author': '@vimalvimal4263',
#   'Comment_Published': '2023-02-06T13:44:58Z'},
#  {'Comment_Id': 'Ugy8ljkS1j2XK8ZgKYt4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'Ss squad 👽',
#   'Comment_Author': '@leeleonardo6152',
#   'Comment_Published': '2023-02-06T13:31:50Z'},
#  {'Comment_Id': 'UgyBYiX0XakmldaQAdh4AaABAg',
#   'Video_Id': 'qIyIA68T1FY',
#   'Comment_Text': 'LMES , Mr Gk வரிசையில் இப்போது <br>Science With Sam 🔥🔥🔥',
#   'Comment_Author': '@prabanjan.pkavaskar.p7449',
#   'Comment_Published': '2023-02-06T13:31:49Z'},
#  {'Comment_Id': 'UgzzVSfFp8m8kPZEHb94AaABAg',
#   'Video_Id': 'PoS7ifimbpk',
#   'Comment_Text': 'Anna unga number send pannunga',
#   'Comment_Author': '@arjungaming6725',
#   'Comment_Published': '2024-03-19T17:32:01Z'},
#  ...]

# %%
#get_playlist_details

def get_playlist_details(channel_id):
        next_page_token=None
        All_data=[]
        while True:
                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(Playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_count=item['contentDetails']['itemCount'])
                        All_data.append(data)

                next_page_token=response.get('nextPagetoken')
                if next_page_token is None:
                        break
        return All_data

# %%
#playlist_details=get_playlist_details('UC8K9ptYhFDTtnUDoz95WJQw')

# %%
#len(playlist_details)
# Out:
# 17

# %%
#response['items'][0]['snippet']['publishedAt']

# %%
#upload to mongoDB

client=pymongo.MongoClient("mongodb+srv://achantatejanjani14:Tejanjani1406@tejanjani.xiyuhwu.mongodb.net/?retryWrites=true&w=majority&appName=Tejanjani")
db=client["Youtube_data"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"Playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
#insert=channel_details("UC8K9ptYhFDTtnUDoz95WJQw")
#insert=channel_details("UCZfEMddu3u3l4Ug0tzM3TMA")
#insert=channel_details("UCoWAx3Yd9pc_TCixc4XTKiQ")
#insert=channel_details("UChGd9JY4yMegY6PxqpBjpRA")

# %%
insert
# Out:
# 'upload completed successfully'

# %%
#Table creation for channels,playlists,videos,comments

def channels_table(channel_name_s): 
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    #drop_query='''drop table if exists channels'''
    #cursor.execute(drop_query)
    #mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(80) primary key,
                                                            Subscribers bigint,
                                                            Views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()

    except:
        print("Channel table already created")


    #fetching all datas
    query_1="SELECT * FROM channels"
    cursor.execute(query_1)
    table=cursor.fetchall()
    mydb.commit()

    chann_list=[]
    chann_list2=[]
    df_all_channels=pd.DataFrame(table)

    chann_list.append(df_all_channels[0])
    for i in chann_list[0]:
        chann_list2.append(i)
    
    if channel_name_s in chann_list2:
        news= f"Your Provided channel{channel_name_s} is already exists"
        return news
    
    else:
        single_channel_details=[]
        coll1=db["channel_details"]
        for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
            single_channel_details.append(ch_data["channel_information"])
        
        df_single_channel=pd.DataFramw(single_channel_details)

    #ch_list=[]
    #db=client["Youtube_data"]
    #coll1=db["channel_details"]
    #for ch_data in coll1.find({},{"_id":0,"Channel_information":1}):
        #ch_list.append(ch_data["Channel_information"][i])
    #df1=pd.DataFrame(ch_list)



    for index,row in df_single_channel.iterrows():
        insert_query='''insert into channels(Channel_Name,Channel_id,Subscribers,Views,Total_Videos,Channel_Description,Playlist_Id)
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_id'],
                row['Subscribers'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])
        
        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("channels values are already inserted")

# %%
def playlist_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    #drop_query='''drop table if exists playlists'''
    #cursor.execute(drop_query)
    #mydb.commit()

    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp,
                                                        Video_Count int
                                                        )'''

    cursor.execute(create_query)
    mydb.commit()

    single_channel_details= []
    coll1=db["channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
        single_channel_details.append(ch_data["playlist_information"])

    df_single_channel= pd.DataFrame(single_channel_details[0])

    #pl_list=[]
    #db=client["Youtube_data"]
    #coll1=db["channel_details"]
    #for pl_data in coll1.find({},{"_id":0,"Playlist_information":1}):
       # for i in range(len(pl_data["Playlist_information"])):
           # pl_list.append(pl_data["Playlist_information"][i])
    #df1=pd.DataFrame(pl_list)

    for index,row in df_single_channel.iterrows():
        insert_query='''insert into playlists(Playlist_Id,Title,Channel_Id,Channel_Name,PublishedAt,Video_count)values(%s,%s,%s,%s,%s,%s)'''
        values=(row['Playlist_Id'],
            row['Title'],
            row['Channel_Id'],
            row['Channel_Name'],
            row['PublishedAt'],
            row['Video_count'])

    cursor.execute(insert_query,values)
    mydb.commit()

# %%
def videos_table(channel_name_s):

    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    #drop_query='''drop table if exists videos'''
    #cursor.execute(drop_query)
    #mydb.commit()

    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint ,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50))'''

    cursor.execute(create_query)
    mydb.commit()

    single_channel_details= []
    coll1=db["channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
        single_channel_details.append(ch_data["video_information"])

    df_single_channel= pd.DataFrame(single_channel_details[0])


    #vi_list=[]
    #db=client["Youtube_data"]
    #coll1=db["channel_details"]
    #for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        #for i in range(len(vi_data["video_information"])):
            #vi_list.append(vi_data["video_information"][i])
    #df2=pd.DataFrame(vi_list)


    for index,row in df_single_channel.iterrows():
            insert_query='''insert into videos(Channel_Name,
                                            Channel_Id,
                                            Video_Id,
                                            Title,
                                            Tags,
                                            Thumbnail,
                                            Description,
                                            Published_Date,
                                            Duration,
                                            Views,
                                            Likes,
                                            Comments,
                                            Favorite_Count,
                                            Definition,
                                            Caption_Status)values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
            
            values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Description'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_Count'],
                row['Definition'],
                row['Caption_Status'])

            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def comments_table(channel_name_s):
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
    cursor=mydb.cursor()

    #drop_query='''drop table if exists comments'''
    #cursor.execute(drop_query)
    #mydb.commit()

    create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp)'''

    cursor.execute(create_query)
    mydb.commit()

    single_channel_details= []
    coll1=db["channel_details"]
    for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
        single_channel_details.append(ch_data["comment_information"])

    df_single_channel= pd.DataFrame(single_channel_details[0])


    #com_list=[]
    #db=client["Youtube_data"]
    #coll1=db["channel_details"]
    #for com_data in coll1.find({},{"_id":0,"comment_information":1}):
     #   for i in range(len(com_data["comment_information"])):
    #        com_list.append(com_data["comment_information"][i])
    #df3=pd.DataFrame(com_list)

    for index,row in df_single_channel.iterrows():
            insert_query='''insert into comments(Comment_Id,
                                            Video_Id,
                                            Comment_Text,
                                            Comment_Author,
                                            Comment_Published
                                            )
                                            values(%s,%s,%s,%s,%s)'''

            values=(row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text'],
                row['Comment_Author'],
                row['Comment_Published'])
        
            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def tables(channel_name):

    news= channels_table(channel_name)
    if news:
        st.write(news)
    else:
        playlist_table(channel_name)
        videos_table(channel_name)
        comments_table(channel_name)

    return "Tables Created Successfully"

# %%
def show_channels_table():
    ch_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
    df=st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    pl_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for pl_data in coll1.find({},{"_id":0,"Playlist_information":1}):
        for i in range(len(pl_data["Playlist_information"])):
            pl_list.append(pl_data["Playlist_information"][i])
    df1=st.dataframe(pl_list)

    return df1

# %%
def show_videos_table():
    vi_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2=st.dataframe(vi_list)

    return df2

# %%
def show_comments_table():
    com_list=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
    df3=st.dataframe(com_list)

    return df3

# %%
#streamlit part

with st.sidebar:
    st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Skill Take Away")
    st.caption("Python Scripting")
    st.caption("Data Collection")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MomgoDB and SQL")

channel_id=st.text_input("Enter the channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db=client["Youtube_data"]
    coll1=db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["Channel_id"])

    if channel_id in ch_ids:
        st.success("Channel Details of the given channel id already exists")
    else:
        insert=channel_details(channel_id)
        st.success(insert)


all_channels= []
coll1=db["channel_details"]
for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
    all_channels.append(ch_data["channel_information"]["Channel_Name"])
        
unique_channel= st.selectbox("Select the Channel",all_channels)

if st.button("Migrate to Sql"):
    Table=tables(unique_channel)
    st.success(Table)


show_table=st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()

elif show_table=="PLAYLISTS":
    show_playlists_table()

elif show_table=="VIDEOS":
    show_videos_table()

elif show_table=="COMMENTS":
    show_comments_table()
# Out:
# 2024-05-07 00:12:28.509
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Tejanjani\OneDrive\Desktop\Capstone project\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
#SQL CONNECTION

mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

question=st.selectbox("Select your Question",("1. All the videos and the channels name",
                                              "2. Channels with most number of videos",
                                              "3. 10 most viewed videos",
                                              "4. Comments in each videos",
                                              "5. Videos with highest likes",
                                              "6. Likes of all videos",
                                              "7. Views of each channel",
                                              "8. Videos Published in the Year of 2024",
                                              "9. Average Duration of all videos in each channel",
                                              "10. Videos with highest number of comments"))

if question=="1. All the videos and the channels name":
    query1='''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1=cursor.fetchall()
    df=pd.DataFrame(t1,columns=["video title","channel name"])
    st.write(df)

elif question=="2. Channels with most number of videos":
    query2='''select channel_name as channelname,total_videos as no_videos from channels
                order by total_videos'''
    cursor.execute(query2)
    mydb.commit()
    t2=cursor.fetchall()
    df2=pd.DataFrame(t1,columns=["channel_name","No of videos"])
    st.write(df2)

elif question=="3. 10 most viewed videos":
    query3='''select views as views,channel_name as channelname,title as videotitle from videos 
                where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3=cursor.fetchall()
    df3=pd.DataFrame(t3,columns=["views","channel name","videotitle"])
    st.write(df3)

elif question=="4. comments in each videos":
    query4='''select comments as no_comments,title as videotitle from videos where comments is not null'''
    cursor.execute(query4)
    mydb.commit()
    t4=cursor.fetchall()
    df4=pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)

elif question=="5. Videos with higest likes":
    query5='''select title as videotitle,channel_name as channelname,likes as likecount
                from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5=cursor.fetchall()
    df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)

elif question=="6. likes of all videos":
    query6='''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6=cursor.fetchall()
    df6=pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question=="7. views of each channel":
    query7='''select channel_name as channelname ,views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7=cursor.fetchall()
    df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.write(df7)

elif question=="8. videos published in the year of 2022":
    query8='''select title as video_title,published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8=cursor.fetchall()
    df8=pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)

elif question=="9. average duration of all videos in each channel":
    query9='''select channel_name as channelname,AVG(duration) as averageduration from videos group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9=cursor.fetchall()
    df9=pd.DataFrame(t9,columns=["channelname","averageduration"])

    T9=[]
    for index,row in df9.iterrows():
        channel_title=row["channelname"]
        average_duration=row["averageduration"]
        average_duration_str=str(average_duration)
        T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
    df1=pd.DataFrame(T9)
    st.write(df1)

elif question=="10. videos with highest number of comments":
    query10='''select title as videotitle, channel_name as channelname,comments as comments from videos where comments is
                not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10=cursor.fetchall()
    df10=pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)

# %%
mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="123456",
                        database="youtube_data",
                        port="5432")
cursor=mydb.cursor()

#if question=="1. All the videos and the channels name":
query1='''select title as videos,channel_name as channelname from videos'''
cursor.execute(query1)
mydb.commit()
t1=cursor.fetchall()
df=pd.DataFrame(t1,columns=["video title","channel name"])
df
# Out:
#                                             video title  \
# 0     Who is C V Raman? What is Raman Effect? Why is...
# 1     Erwin Schrodinger - Life Story - 3| Tamil | Co...
# 2     Erwin Schrodinger - Life Story | Tamil | Part ...
# 3     Erwin Schrodinger  - Life Story | Tamil | Part...
# 4     உங்களால் எனக்கு கிடைத்த முதல் விருது | அனைவருக...
# ...                                                 ...
# 1703                 The Haunting of Mercyvale Hospital
# 1704  Rainy Night Drive Horror Stories | Vol. 1 (Com...
# 1705            Creepy True Home Alone Lockdown Stories
# 1706                   2 Scary True Horror Stories (V1)
# 1707  The Enigmatic Tale of The Exe Murderer: Unrave...
#
#                                channel name
# 0     Science With Sam - அறிவியல் அறிவோம் !
# 1     Science With Sam - அறிவியல் அறிவோம் !
# 2     Science With Sam - அறிவியல் அறிவோம் !
# 3     Science With Sam - அறிவியல் அறிவோம் !
# 4     Science With Sam - அறிவியல் அறிவோம் !
# ...                                     ...
# 1703                      Spectral Whispers
# 1704                      Spectral Whispers
# 1705                      Spectral Whispers
# 1706                      Spectral Whispers
# 1707                      Spectral Whispers
#
# [1708 rows x 2 columns]
